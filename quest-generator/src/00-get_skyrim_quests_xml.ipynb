# %%
import xml.etree.ElementTree as ET

# %%
tree = ET.parse('elderscrolls_pages_current.xml')
root = tree.getroot()

# %%
for i, e in enumerate(root.iter()):
    print(e.tag)
    if i == 100:
        break
# Out:
# mediawiki
# siteinfo
# sitename
# dbname
# base
# generator
# case
# namespaces
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# namespace
# page
# title
# ns
# id
# revision
# id
# parentid
# timestamp
# contributor
# username
# id
# text
# sha1
# page
# title
# ns
# id
# revision
# id
# parentid
# timestamp
# contributor
# username
# id
# minor
# comment
# text
# sha1
# page
# title
# ns
# id
# revision
# id
# parentid
# timestamp
# contributor
# username
# id
# comment
# text
# sha1
# page
# title
# ns
# id
# revision
# id
# parentid
# timestamp
# contributor
# ...

# %%
skyrim_quests = root.find('./page/[title="Quests (Skyrim)"]')

# %%
quest_index_text = skyrim_quests.find('revision').find('text').text

# %%
print(quest_index_text)
# Out:
# {{WikiaVideos}}
# {{TOCright}}
# {{For|2=Quest}}
# '''Quests''' are tasks the [[Last Dragonborn|Dragonborn]] can perform in {{Skyrim}}. Various actions, such as talking to people, reading books, etc., can initiate quests, allowing for rewards to be gained by completing them. Rewards may include gold, [[Items (Skyrim)|items]], increases of [[Skills (Skyrim)|skill levels]]. Successfully completing a quest for a person makes them friendly to the Dragonborn, opening opportunities in many cases to recruit [[Follower (Skyrim)|followers]] or make [[Marriage (Skyrim)|marriage]] proposals.
#
# ...
